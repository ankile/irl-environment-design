# %%
from maze_env import ConstructedMazeEnv

# %%
env = ConstructedMazeEnv()

# %%
env.render()
# Out:
# array([[[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        ...,
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
# ...
